# %%
import pandas as pd
import bamboolib as bam

# %%
df = pd.read_excel('2010-2018-faculty-by-country-of-nationality.xlsx')

# %%
df
# Out:
#           year       Nationality  Faculty
# 0    Fall 2010           Algeria      1.0
# 1    Fall 2010           Armenia      NaN
# 2    Fall 2010         Australia     36.0
# 3    Fall 2010           Austria      NaN
# 4    Fall 2010           Bahrain      NaN
# 5    Fall 2010        Bangladesh      1.0
# 6    Fall 2010           Belgium      1.0
# 7    Fall 2010            Brazil      NaN
# 8    Fall 2010  British Ind. O T      NaN
# 9    Fall 2010          Bulgaria      1.0
# 10   Fall 2010            Canada     54.0
# 11   Fall 2010             China      3.0
# 12   Fall 2010          Colombia      1.0
# 13   Fall 2010           Croatia      NaN
# 14   Fall 2010            Cyprus      NaN
# 15   Fall 2010           Denmark      2.0
# 16   Fall 2010             Egypt     22.0
# 17   Fall 2010          Ethiopia      NaN
# 18   Fall 2010            France      3.0
# 19   Fall 2010     French Guiana      1.0
# 20   Fall 2010           Germany      5.0
# ...
